# %%
name_input=input('Please tell me your name:  ')

print('\nHello, '+name_input+'!\n')
print('WELCOME TO THE NUMBER GUESSING GAME CHALLENGE!\n\nWe will pick a random integer from 1 to 100 and you will guess the integer.')
print('\nThe rules are the following:')
print('\n\t1. Your guess must be between 1 and 100 - no exceptions to this!')
print('\n\t2. For your first guess: \n\t   > If it is within 10 of the integer, you will get "VERY WARM!"\n\t   > If it is further than 10 away from the integer, you will get "VERY COLD!"')
print('\n\t3. On all subsequent guesses: \n\t   > If it is closer to the integer than the previous guess, you will get "WARMER!" \n\t   > If it is farther from the integer than the previous guess, you will get "COLDER!"')
print('\n\t4. When you guess the integer correctly, we will tell you how many guesses it took!')
print('\nGood luck!')
print('\nNOW SELECTING SUPER SECRET INTEGER! ....\n')
print('Ready for your guesses.\n')

from random import randint
autoselect_num=randint(1,101)

guess_list=[]

guess_input=int(input('Please provide a number between 1 and 100.   '))

while True:
    if guess_input>=1 and guess_input<=100:
        guess_list.append(guess_input)
        print(guess_list)
        if guess_input==autoselect_num:
            print('\t > You guessed the integer correctly!'+' Number of attempts: '+str(len(guess_list)))
            break    
        elif guess_input>=autoselect_num-10 and guess_input<=autoselect_num:
            print('VERY WARM!')
            break
        elif guess_input<=autoselect_num+10 and guess_input>=autoselect_num:
            print('VERY WARM!')
            break
        elif guess_input<autoselect_num-10 and guess_input>=1:
            print('VERY COLD!')
            break
        elif guess_input>autoselect_num+10 and guess_input<=100:
            print('VERY COLD!')
            break
    elif guess_input<=1 or guess_input>=100:
        print('OUT OF BOUNDS!')
        guess_input=int(input('Please provide a number between 1 and 100.   '))

guess_input2=int(input('Please provide a number between 1 and 100.   '))

while True:
    if guess_input2>=1 and guess_input2<=100:
        guess_list.append(guess_input2)
        print(guess_list)
        if guess_input2==autoselect_num:
            print('\t > You guessed the integer correctly!'+' Number of attempts: '+str(len(guess_list)))
            break   
        elif abs(autoselect_num-guess_input2)>abs(autoselect_num-guess_list[-2]):
            print('COLDER!')
        elif abs(autoselect_num-guess_input2)<abs(autoselect_num-guess_list[-2]):
            print('WARMER!')
        guess_input2=int(input('Please provide a number between 1 and 100.   '))
    elif guess_input2<=1 or guess_input2>=100:
        print('OUT OF BOUNDS!')
        guess_input2=int(input('Please provide a number between 1 and 100.   '))
